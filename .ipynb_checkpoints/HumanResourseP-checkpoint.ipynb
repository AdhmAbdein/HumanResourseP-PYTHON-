# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Data

# %%
HR = pd.read_csv('datasets/HRData.csv')

# %%
HR
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %%
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EmployeeID            311 non-null    int64
#  1   EmployeeName          311 non-null    object
#  2   Salary                311 non-null    int64
#  3   Position              311 non-null    object
#  4   State                 311 non-null    object
#  5   DateOfBirth           311 non-null    object
#  6   Gender                311 non-null    object
#  7   MaritalStatus         311 non-null    object
#  8   HiringDate            311 non-null    object
#  9   TerminationDate       104 non-null    object
#  10  EmploymentStatus      311 non-null    object
#  11  Department            311 non-null    object
#  12  RecruitmentSource     311 non-null    object
#  13  PerformanceScore      311 non-null    object
#  14  EngagementSurvey      311 non-null    float64
# ...

# %%
HR.describe()
# Out:
#        EmployeeID         Salary  EngagementSurvey  EmployeeSatisfaction
# count  311.000000     311.000000        311.000000            311.000000
# mean   156.000000   69020.684887          4.110000              3.890675
# std     89.922189   25156.636930          0.789938              0.909241
# min      1.000000   45046.000000          1.120000              1.000000
# 25%     78.500000   55501.500000          3.690000              3.000000
# 50%    156.000000   62810.000000          4.280000              4.000000
# 75%    233.500000   72036.000000          4.700000              5.000000
# max    311.000000  250000.000000          5.000000              5.000000

# %%
HR['Salary'].describe()
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 25%       55501.500000
# 50%       62810.000000
# 75%       72036.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Detecting Outliers

# %%
plt.boxplot(HR['Salary'])
plt.show()

# %% [markdown]
# ## Detecting Null Values and fill null

# %%
HR.isna().sum()
# Out:
# EmployeeID                0
# EmployeeName              0
# Salary                    0
# Position                  0
# State                     0
# DateOfBirth               0
# Gender                    0
# MaritalStatus             0
# HiringDate                0
# TerminationDate         207
# EmploymentStatus          0
# Department                0
# RecruitmentSource         0
# PerformanceScore          0
# EngagementSurvey          0
# EmployeeSatisfaction      0
# dtype: int64

# %%
HR['TerminationDate'].fillna('11/11/1900' , inplace=True)

# %%
HR = HR.replace('11/11/900' , '11/11/1900')

# %%
HR['TerminationDate']
# Out:
# 0      11/11/1900
# 1       6/16/2016
# 2       9/24/2012
# 3      11/11/1900
# 4        9/6/2016
#           ...
# 306    11/11/1900
# 307     9/29/2015
# 308    11/11/1900
# 309    11/11/1900
# 310    11/11/1900
# Name: TerminationDate, Length: 311, dtype: object

# %%
HR
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %% [markdown]
# ## Change data type

# %%
HR['DateOfBirth']= pd.to_datetime(HR['DateOfBirth'])
# Out:
# C:\Users\fg_DELL\AppData\Local\Temp\ipykernel_18956\2477869771.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   HR['DateOfBirth']= pd.to_datetime(HR['DateOfBirth'])

# %%
HR['HiringDate']= pd.to_datetime(HR['HiringDate'])

# %%
HR['TerminationDate']= pd.to_datetime(HR['TerminationDate'])

# %%
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EmployeeID            311 non-null    int64
#  1   EmployeeName          311 non-null    object
#  2   Salary                311 non-null    int64
#  3   Position              311 non-null    object
#  4   State                 311 non-null    object
#  5   DateOfBirth           311 non-null    datetime64[ns]
#  6   Gender                311 non-null    object
#  7   MaritalStatus         311 non-null    object
#  8   HiringDate            311 non-null    datetime64[ns]
#  9   TerminationDate       311 non-null    datetime64[ns]
#  10  EmploymentStatus      311 non-null    object
#  11  Department            311 non-null    object
#  12  RecruitmentSource     311 non-null    object
#  13  PerformanceScore      311 non-null    object
# ...

# %%
HR['EngagementSurvey'].astype(float)
# Out:
# 0      4.60
# 1      4.96
# 2      3.02
# 3      4.84
# 4      5.00
#        ...
# 306    4.07
# 307    3.20
# 308    4.60
# 309    5.00
# 310    4.50
# Name: EngagementSurvey, Length: 311, dtype: float64

# %%
HR['EmployeeSatisfaction'].astype('int64')
# Out:
# 0      5
# 1      3
# 2      3
# 3      5
# 4      4
#       ..
# 306    4
# 307    2
# 308    5
# 309    3
# 310    5
# Name: EmployeeSatisfaction, Length: 311, dtype: int64

# %%
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EmployeeID            311 non-null    int64
#  1   EmployeeName          311 non-null    object
#  2   Salary                311 non-null    int64
#  3   Position              311 non-null    object
#  4   State                 311 non-null    object
#  5   DateOfBirth           311 non-null    datetime64[ns]
#  6   Gender                311 non-null    object
#  7   MaritalStatus         311 non-null    object
#  8   HiringDate            311 non-null    datetime64[ns]
#  9   TerminationDate       311 non-null    datetime64[ns]
#  10  EmploymentStatus      311 non-null    object
#  11  Department            311 non-null    object
#  12  RecruitmentSource     311 non-null    object
#  13  PerformanceScore      311 non-null    object
# ...

# %% [markdown]
# ## Detecting duplicated rows

# %%
HR.duplicated().sum()
# Out:
# 0

# %%
HR.duplicated('EmployeeID').sum()
# Out:
# 0

# %% [markdown]
# # Analysing Data

# %% [markdown]
# ## What is the overall distribution of employee positions ?

# %%
HR['Position'].value_counts()
# Out:
# Position
# Production Technician I         137
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                10
# IT Support                        8
# Data Analyst                      7
# Sr. Network Engineer              5
# Database Administrator            5
# Network Engineer                  5
# BI Developer                      4
# Senior BI Developer               3
# Administrative Assistant          3
# Sales Manager                     3
# Accountant I                      3
# Sr. DBA                           2
# IT Manager - DB                   2
# Sr. Accountant                    2
# Director of Operations            1
# Shared Services Manager           1
# Data Analyst                      1
# Data Architect                    1
# Principal Data Architect          1
# IT Manager - Infra                1
# President & CEO                   1
# Enterprise Architect              1
# ...

# %% [markdown]
# ## What is the average salary for each position in the company?

# %%
HR.groupby('Position')['Salary'].mean().round()
# Out:
# Position
# Accountant I                     63508.0
# Administrative Assistant         52280.0
# Area Sales Manager               64933.0
# BI Developer                     95465.0
# BI Director                     110929.0
# CIO                             220450.0
# Data Analyst                     89933.0
# Data Analyst                     88527.0
# Data Architect                  150290.0
# Database Administrator          108500.0
# Director of Operations          170500.0
# Director of Sales               180000.0
# Enterprise Architect            103613.0
# IT Director                     178000.0
# IT Manager - DB                 144960.0
# IT Manager - Infra              157000.0
# IT Manager - Support            138888.0
# IT Support                       63684.0
# Network Engineer                 61605.0
# President & CEO                 250000.0
# Principal Data Architect        120000.0
# Production Manager               75294.0
# Production Technician I          55524.0
# ...

# %% [markdown]
# ## Employee satisfaction based on gender and position?

# %%
HR.groupby(['Gender' , 'Position'])['EmployeeSatisfaction'].mean().round().unstack()
# Out:
# Position  Accountant I  Administrative Assistant  Area Sales Manager  \
# Gender
# F                  2.0                       3.0                 4.0
# M                  4.0                       NaN                 4.0
#
# Position  BI Developer  BI Director  CIO  Data Analyst  Data Analyst   \
# Gender
# F                  4.0          NaN  5.0           4.0            NaN
# M                  4.0          5.0  NaN           4.0            3.0
#
# Position  Data Architect  Database Administrator  ...  \
# Gender                                            ...
# F                    3.0                     4.0  ...
# M                    NaN                     3.0  ...
#
# Position  Production Technician I  Production Technician II  Sales Manager  \
# Gender
# F                             4.0                       4.0            4.0
# M                             4.0                       4.0            4.0
#
# ...

# %% [markdown]
# ## What is the distribution of employees across different states?

# %%
HR['State'].value_counts()
# Out:
# State
# MA    276
# CT      6
# TX      3
# VT      2
# UT      1
# AZ      1
# ND      1
# OR      1
# MT      1
# NV      1
# ID      1
# KY      1
# NC      1
# FL      1
# GA      1
# CO      1
# NY      1
# PA      1
# RI      1
# NH      1
# TN      1
# IN      1
# OH      1
# CA      1
# WA      1
# AL      1
# VA      1
# ME      1
# Name: count, dtype: int64

# %% [markdown]
# ## What is the average salary  between male and female employees?

# %%
HR.groupby('Gender')['Salary'].mean().round()
# Out:
# Gender
# F     67787.0
# M     70629.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## Time_to_termination

# %%
HR['time_to_termination'] = (HR['TerminationDate'] - HR['HiringDate']).dt.days

# %%
HR
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %%
HR['time_to_termination'] = HR['time_to_termination'].apply(lambda x: max(0, x))

# %%
HR
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %% [markdown]
# ## What is the average time between hiring and termination for employees?

# %%
HR['time_to_termination'].mean().round()
# Out:
# 423.0

# %% [markdown]
# ## Number of employees depend on status and departments?

# %%
HR.groupby(['Department' ,'EmploymentStatus']).agg({'EmployeeID' :'count'})
# Out:
#                                           EmployeeID
# Department        EmploymentStatus
# Admin Offices     Active                           7
#                   Terminated for Cause             1
#                   Voluntarily Terminated           1
# Engineering       Active                           7
#                   Terminated for Cause             1
#                   Voluntarily Terminated           3
# Executive Office  Active                           1
# IT/IS             Active                          40
#                   Terminated for Cause             4
#                   Voluntarily Terminated           6
# Production        Active                         126
#                   Terminated for Cause             8
#                   Voluntarily Terminated          75
# Sales             Active                          26
#                   Terminated for Cause             2
#                   Voluntarily Terminated           3

# %% [markdown]
# ## Identify the influencing of recruitment sources for different positions?

# %%
HR.groupby(['Position' , 'RecruitmentSource']).agg({'EmployeeID' :'count'})
# Out:
#                                              EmployeeID
# Position                 RecruitmentSource
# Accountant I             Diversity Job Fair           1
#                          Indeed                       1
#                          Website                      1
# Administrative Assistant Diversity Job Fair           1
#                          Indeed                       1
# ...                                                 ...
# Sr. Accountant           Other                        1
# Sr. DBA                  Indeed                       1
#                          LinkedIn                     1
# Sr. Network Engineer     Employee Referral            3
#                          LinkedIn                     2
#
# [80 rows x 1 columns]

# %% [markdown]
# ## Calculate the age of each employee

# %%
current_date = pd.to_datetime('now')
current_date
HR['Age']= current_date - HR['DateOfBirth']

# %%
HR['Age'] // np.timedelta64(1, 'Y')
# Out:
# 0      40
# 1      48
# 2      35
# 3      35
# 4      34
#        ..
# 306    38
# 307    41
# 308    44
# 309    44
# 310    45
# Name: Age, Length: 311, dtype: int64

# %%
HR['Age']=HR['Age'] // np.timedelta64(1, 'Y')

# %%
HR['Age']
# Out:
# 0      40
# 1      48
# 2      35
# 3      35
# 4      34
#        ..
# 306    38
# 307    41
# 308    44
# 309    44
# 310    45
# Name: Age, Length: 311, dtype: int64

# %% [markdown]
# ## How does engagement survey scores diffrent across different positions?

# %%
HR.groupby('Position').agg({'EngagementSurvey' :'mean'}).round(2)
# Out:
#                               EngagementSurvey
# Position
# Accountant I                              4.47
# Administrative Assistant                  4.01
# Area Sales Manager                        3.79
# BI Developer                              3.75
# BI Director                               4.50
# CIO                                       4.60
# Data Analyst                              4.09
# Data Analyst                              4.20
# Data Architect                            4.94
# Database Administrator                    4.33
# Director of Operations                    3.70
# Director of Sales                         4.50
# Enterprise Architect                      3.50
# IT Director                               5.00
# IT Manager - DB                           3.95
# IT Manager - Infra                        2.39
# IT Manager - Support                      4.30
# IT Support                                4.54
# Network Engineer                          3.66
# ...

# %% [markdown]
# ## What is the overall employee satisfaction score for organization?

# %%
HR['EmployeeSatisfaction'].mean().round(2)
# Out:
# 3.89

# %% [markdown]
# ## Identify any patterns in employee engagement based on gender?

# %%
HR.groupby('Gender')['EngagementSurvey'].mean().round(2)
# Out:
# Gender
# F     4.14
# M     4.08
# Name: EngagementSurvey, dtype: float64

# %% [markdown]
# ## How does the distribution of employee across performance score and departments?

# %%
HR.groupby(['Department' , 'PerformanceScore'])['EmployeeID'].count()
# Out:
# Department         PerformanceScore
# Admin Offices      Fully Meets            9
# Engineering        Exceeds                2
#                    Fully Meets            8
#                    Needs Improvement      1
# Executive Office   Fully Meets            1
# IT/IS              Exceeds                6
#                    Fully Meets           42
#                    Needs Improvement      1
#                    PIP                    1
# Production         Exceeds               27
#                    Fully Meets          159
#                    Needs Improvement     15
#                    PIP                    8
# Sales              Exceeds                2
#                    Fully Meets           24
#                    Needs Improvement      1
#                    PIP                    4
# Name: EmployeeID, dtype: int64

# %% [markdown]
# ## What is the distribution of employee satisfaction scores by department?

# %%
HR.groupby('Department')['EmployeeSatisfaction'].mean().round(2)
# Out:
# Department
# Admin Offices        3.56
# Engineering          4.09
# Executive Office     3.00
# IT/IS                3.96
# Production           3.86
# Sales                4.03
# Name: EmployeeSatisfaction, dtype: float64

# %%
HR
# Out:
#      EmployeeID      EmployeeName  Salary                  Position State  \
# 0             1        John Smith   62506   Production Technician I    MA
# 1             2     Sarah Johnson  104437                   Sr. DBA    MA
# 2             3  Michael Williams   64955  Production Technician II    MA
# 3             4       Emily Brown   64991   Production Technician I    MA
# 4             5       David Jones   50825   Production Technician I    MA
# ..          ...               ...     ...                       ...   ...
# 306         307        Nana Asare   65893  Production Technician II    MA
# 307         308        Yaa Yeboah   48513   Production Technician I    MA
# 308         309        Kojo Ofori  220450                       CIO    MA
# 309         310        Esi Amoako   89292              Data Analyst    MA
# 310         311       Kweku Annan   45046   Production Technician I    MA
#
#     DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# ...

# %%
HR.groupby('Department')['Age'].mean()
# Out:
# Department
# Admin Offices        37.777778
# Engineering          32.181818
# Executive Office    -31.000000
# IT/IS                13.680000
# Production           20.607656
# Sales                 9.161290
# Name: Age, dtype: float64

# %%
HR.head(10)
# Out:
#    EmployeeID        EmployeeName  Salary                  Position State  \
# 0           1          John Smith   62506   Production Technician I    MA
# 1           2       Sarah Johnson  104437                   Sr. DBA    MA
# 2           3    Michael Williams   64955  Production Technician II    MA
# 3           4         Emily Brown   64991   Production Technician I    MA
# 4           5         David Jones   50825   Production Technician I    MA
# 5           6       Jessica Davis   57568   Production Technician I    MA
# 6           7  Christopher Miller   95660         Software Engineer    MA
# 7           8       Ashley Wilson   59365   Production Technician I    MA
# 8           9    Matthew Anderson   47837   Production Technician I    MA
# 9          10     Samantha Taylor   50178                IT Support    MA
#
#   DateOfBirth Gender MaritalStatus HiringDate TerminationDate  \
# 0  1983-07-10     M         Single 2011-07-05      1900-11-11
# ...

# %%
rows_drop = HR[HR['Age'] < 0].index
rows_drop
# Out:
# Index([  8,  16,  17,  20,  21,  24,  25,  27,  31,  32,  35,  40,  41,  42,
#         45,  59,  61,  68,  69,  76,  78,  79,  89,  98,  99, 103, 104, 108,
#        111, 112, 121, 124, 127, 131, 139, 140, 142, 143, 145, 150, 151, 152,
#        155, 157, 174, 175, 185, 191, 197, 201, 206, 225, 226, 230, 232, 234,
#        239, 240, 243, 244, 246, 254, 257, 260, 261, 263, 265, 273, 277, 278,
#        279, 281, 282, 287, 290, 296, 301, 303, 304],
#       dtype='int64')

# %%
HR.drop(rows_drop, inplace=True)

# %%
HR.loc[HR['Age'] < 0]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, EmployeeName, Salary, Position, State, DateOfBirth, Gender, MaritalStatus, HiringDate, TerminationDate, EmploymentStatus, Department, RecruitmentSource, PerformanceScore, EngagementSurvey, EmployeeSatisfaction, time_to_termination, Age]
# Index: []

# %% [markdown]
# ## What is the average age of employees in each department?

# %%
HR.groupby('Department')['Age'].mean().round()
# Out:
# Department
# Admin Offices        38.0
# Engineering          40.0
# IT/IS                39.0
# Production           41.0
# Sales                38.0
# Name: Age, dtype: float64

# %% [markdown]
# ## How does the average salary differ between different department?

# %%
HR.groupby('Department')['Salary'].mean().round()
# Out:
# Department
# Admin Offices        71792.0
# Engineering          96719.0
# IT/IS                93239.0
# Production           59869.0
# Sales                64683.0
# Name: Salary, dtype: float64

# %%
HR['EmploymentStatus'].unique()
# Out:
# array(['Active', 'Voluntarily Terminated', 'Terminated for Cause'],
#       dtype=object)

# %% [markdown]
# ## How does the average salary across different states?

# %%
HR.groupby('State')['Salary'].mean().round()
# Out:
# State
# AL    61568.0
# AZ    57859.0
# CA    74241.0
# CO    65310.0
# CT    51777.0
# FL    63051.0
# GA    63695.0
# IN    61555.0
# KY    61844.0
# MA    67618.0
# ME    55875.0
# MT    60120.0
# NC    68829.0
# NH    70545.0
# NV    58273.0
# PA    68999.0
# TX    77810.0
# UT    70468.0
# VT    65729.0
# WA    59231.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## How many employees are there in each state?

# %%
HR_stat = HR.groupby('State').agg({'EmployeeID' : 'count'})
HR_stat
# Out:
#        EmployeeID
# State
# AL              1
# AZ              1
# CA              1
# CO              1
# CT              1
# FL              1
# GA              1
# IN              1
# KY              1
# MA            212
# ME              1
# MT              1
# NC              1
# NH              1
# NV              1
# PA              1
# TX              2
# UT              1
# VT              1
# WA              1

# %%
HR_stat.sort_values( by = 'EmployeeID' , ascending = False)
# Out:
#        EmployeeID
# State
# MA            212
# TX              2
# AL              1
# MT              1
# VT              1
# UT              1
# PA              1
# NV              1
# NH              1
# NC              1
# ME              1
# AZ              1
# KY              1
# IN              1
# GA              1
# FL              1
# CT              1
# CO              1
# CA              1
# WA              1

# %% [markdown]
# ## How does the distribution of engagement survey scores vary by gender?

# %%
HR.groupby('Gender')['EngagementSurvey'].mean().round(2)
# Out:
# Gender
# F     4.12
# M     4.07
# Name: EngagementSurvey, dtype: float64

# %% [markdown]
# ## Age grouping

# %%
HR.loc[HR['Age']<=19, 'Age_group'] = 'teenage'
HR.loc[HR['Age'].between(20,24), 'Age_group'] = 'yadult'
HR.loc[HR['Age'].between(25,39), 'Age_group'] = 'adult'
HR.loc[HR['Age']>39, 'Age_group'] = 'older_adult'

# %%
HR[['Age', 'Age_group']]
# Out:
#      Age    Age_group
# 0     40  older_adult
# 1     48  older_adult
# 2     35        adult
# 3     35        adult
# 4     34        adult
# ..   ...          ...
# 306   38        adult
# 307   41  older_adult
# 308   44  older_adult
# 309   44  older_adult
# 310   45  older_adult
#
# [232 rows x 2 columns]

# %% [markdown]
# ## Identify salary based on department and position?

# %%
HR.groupby(['Department' , 'Position'])['Salary'].mean().round().unstack()
# Out:
# Position           Accountant I  Administrative Assistant  Area Sales Manager  \
# Department
# Admin Offices           63508.0                   52280.0                 NaN
# Engineering                 NaN                       NaN                 NaN
# IT/IS                       NaN                       NaN                 NaN
# Production                  NaN                       NaN                 NaN
# Sales                       NaN                       NaN             63879.0
#
# Position           BI Developer       CIO  Data Analyst  Data Analyst   \
# Department
# Admin Offices               NaN       NaN           NaN            NaN
# Engineering                 NaN       NaN           NaN            NaN
# IT/IS                   95465.0  220450.0       90284.0        88527.0
# Production                  NaN       NaN           NaN            NaN
# Sales                       NaN       NaN           NaN            NaN
#
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=HR['Position'].index , y=HR['Position'].values)
plt.title('Distribution of Employee Positions')
plt.ylabel('Position')
plt.xlabel('Count')
plt.show()
